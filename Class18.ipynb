# %% [markdown]
# ## Matplotlib

# %% [markdown]
# plot 2D/3D curves, surfaces etc.
#
# importantly, contour plots
#
# import matplotlib.pyplot as p

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simple plotting 
x = np.linspace(-5, 5, 100)
y = x**2
plt.plot(x,y)

# %%
plt.plot(x, y, 'o--')

# %%
plt.plot(x, y, 'o')

# %%
plt.plot(x, y, 'o--', color='red', lw = 2.5, ms= 2)

# %%
plt.plot(x, y, '*--', color='green', lw = 2.5, ms= 2)

# %%
#adding figure

plt.figure(figsize=(6,3)) #size of diagram
plt.plot(x, y, 'o-', color='red', lw = 1.5, ms = 2, label = 'par.crv')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(loc='upper right', fontsize = 10)

# %% [markdown]
# ## Using subplots

# %%
#using subplots
x = np.arange(-2.0, 2.0, 0.01)
y = x**2

#Default is single figure
#fig, ax = plt.subplots()

#single axis
fig, ax = plt.subplots(1, 1, figsize = (4,4))
ax.plot(x, y)

ax.set_xlabel('new x-label')
ax.set_ylabel('new y-label')
ax.set_title('Single axis plot')
# ax.set(xlabel='x vlues', ylabel='y values',
title= ('Explicit function y = f(x)')
ax.grid()
plt.show()

# %%
#multiple axis figure

m_fig, m_axes = plt.subplots(2, 2, figsize = (8,4))
ax = m_axes[0][0]  # To plat it in 1st a[0][0] place
ax.plot(x,y)

ay = m_axes[1][1] # To plat it in 1st a[1][1] place
ay.plot(x,y)


ax.set(xlabel='x vlues', ylabel='y values',title='Explicit function y = f(x)')

ax.plot(x ,y)                #x = np.arange(-2.0, 2.0, 0.01) andy = x**2

# ax.set(xlabel='x vlues', ylabel='y values', title='Explicit function y1 = f(x1)')
plt.show()

# %%
# Plotting a curve
# Parametric space curve t, t**2, t**3

t = np.arange(-4.0, 4.0, 0.1)
x = t
y = t**2
z = t**3

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # 111 tells about the distance between two grids
ax.plot(x, y, z)

# %%
fig = plt.figure()
ax = fig.add_subplot(222, projection='3d') # 222 tells about the distance between two grids
ax.plot(x, y, z)

# %%
# Plot elipse
import numpy as np

a = 10
b = 1
t = np.arange(-10.0, 10.0, 0.1)
x = a*np.sin(t)
y = b*np.cos(t)

fig = plt.figure()
ax = fig.add_subplot(111) # 111 tells about the distance between two grids
ax.plot(x, y)

# %%
# Plotting a surface

x = np.arange(-2.0, 2.0, 0.1)
y = np.arange(-2.0, 2.0, 0.1)

# The following will print a 3D surface
X,Y=np.meshgrid(x,y) #Forming MeshGrid
Z = X **2 + Y ** 2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
# Contour plot

fig = plt.figure()

cp = plt.contour(x, y, Z)
plt.clabel(cp, fontsize=8)
plt.show()
